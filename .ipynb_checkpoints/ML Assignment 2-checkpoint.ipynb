# %% [markdown]
# # ML Assignment 2 Using Kaggle's Titanic Dataset/Competition
#
# ## Problem Statement
# To predict the survivors of the Titanic Incident using the following three methods-
# 1. Support Vector Machines (SVM)
# 2. Decision Trees
# 3. Linear Discriminant Analysis

# %%
# Imports 
import pandas as pd
import numpy as np
import random as rng

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

#Data Acquisition
train = pd.read_csv("./train.csv")
test = pd.read_csv("./test.csv")
combine = [train,test]

# %%
train.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.describe(include=['O'])
# Out:
#                        Name   Sex Ticket        Cabin Embarked
# count                   891   891    891          204      889
# unique                  891     2    681          147        3
# top     Peduzzi, Mr. Joseph  male   1601  C23 C25 C27        S
# freq                      1   577      7            4      644

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ## Data Description and Analysis
# 1. Ticket and Cabin need to be fixed as they are currently a mix of data types
# 2. We need to fill NaN values
# 3. We need to further analyse the correlationality of our features.
# 4. Ticket Feature has a very large number of duplicates.

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# ### Correlation matrix
# Correlation Matrix gives us a good idea of how the features are related, we're also closely interested in the correlations between Survived and our geatures. Fare, Pclass and Parch all seem like very good candidates to examine.
# ### Pivot Tables

# %%
train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %% [markdown]
# 62% of the people that survived were in First Class or the First Passenger Class.

# %%
train[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %% [markdown]
# 74% of women survived.

# %%
train[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %% [markdown]
# ### Histograms

# %%
g = sns.FacetGrid(train, col='Survived')
g.map(plt.hist, 'Age', bins=40)

# %% [markdown]
# Thus small children, people between 20 and 40 had the best chance of surviving, that being said, the vast majority of people that died were between 20 and 30 as well

# %%
grid = sns.FacetGrid(train, col='Survived', row='Pclass', size=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=40)
grid.add_legend();

# %% [markdown]
# Unsurprisingly Rich people between the ages of 30 and 40 have a good chance of surviving.

# %%
grid = sns.FacetGrid(train, row='Embarked', col='Survived', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha=.5, ci=None)
grid.add_legend()

# %% [markdown]
# We should possibly create bins for our Fare Feature since Fare depends on Pclass and having a categorical numberset would potentially be better
#
# ## Data Cleanup
# We've decided to drop our ticket and cabin columns from our dataset as they are pretty much useless.

# %%
train = train.drop(['Ticket', 'Cabin'], axis=1)
test = test.drop(['Ticket', 'Cabin'], axis=1)
combine = [train, test]

# %%
train.fillna(0)
test.fillna(0)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %% [markdown]
# Filled our NaNs with 0 and changing sex to a categorical variable

# %%
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

# %%
guess_ages = np.zeros((2,3))
guess_ages
for dataset in combine:
    for i in range(0, 2):
        for j in range(0, 3):
            guess_df = dataset[(dataset['Sex'] == i) & \
                                  (dataset['Pclass'] == j+1)]['Age'].dropna()
            age_guess = guess_df.median()

            # Convert random age float to nearest .5 age
            guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5
            
    for i in range(0, 2):
        for j in range(0, 3):
            dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),\
                    'Age'] = guess_ages[i,j]

    dataset['Age'] = dataset['Age'].astype(int)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
#
#       Fare Embarked
# 0   7.2500        S
# 1  71.2833        C
# 2   7.9250        S
# 3  53.1000        S
# 4   8.0500        S

# %%
train['AgeBand'] = pd.cut(train['Age'], 5)
train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#        AgeBand  Survived
# 0  (-0.08, 16]  0.550000
# 1     (16, 32]  0.337374
# 2     (32, 48]  0.412037
# 3     (48, 64]  0.434783
# 4     (64, 80]  0.090909

# %% [markdown]
# Thus we should split our ages into bins

# %%
for dataset in combine:    
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age']
train = train.drop(['AgeBand'], axis=1)
combine = [train,test]

# %% [markdown]
# Create FamilySize to combine number of Siblings and Parents and a feature to specificy whether a passenger is travelling alone or not

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
for dataset in combine:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1

train[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean()
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
train = train.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
test = test.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
combine = [train, test]
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age     Fare  \
# 0                            Braund, Mr. Owen Harris    0    1   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1    2  71.2833
# 2                             Heikkinen, Miss. Laina    1    1   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1    2  53.1000
# 4                           Allen, Mr. William Henry    0    2   8.0500
#
#   Embarked  IsAlone
# 0        S        0
# 1        C        0
# 2        S        1
# 3        S        0
# 4        S        1

# %% [markdown]
# We also need to fill Embarked - we do it with the most common value

# %%
freq_port = train.Embarked.dropna().mode()[0]
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)
    
train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %%
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

# %%
test['Fare'].fillna(test['Fare'].dropna().median(), inplace=True)
train['Fare'].fillna(train['Fare'].dropna().median(), inplace=True)

# %%
train['FareBand'] = pd.qcut(train['Fare'], 4)
train[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=True)
train = train.drop(['Name', 'PassengerId'], axis=1)
test = test.drop(['Name'], axis=1)
combine = [train, test]

# %%
for dataset in combine:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

train = train.drop(['FareBand'], axis=1)
combine = [train, test]

# %%
X_train = train.drop("Survived", axis=1)
Y_train = train["Survived"]
X_test  = test.drop("PassengerId", axis=1).copy()
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((891, 6), (891,), (418, 6))

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  IsAlone
# 0         0       3    0    1     0         0        0
# 1         1       1    1    2     3         1        0
# 2         1       3    1    1     1         0        1
# 3         1       1    1    2     3         0        0
# 4         0       3    0    2     1         0        1

# %%
X_train.head()
# Out:
#    Pclass  Sex  Age  Fare  Embarked  IsAlone
# 0       3    0    1     0         0        0
# 1       1    1    2     3         1        0
# 2       3    1    1     1         0        1
# 3       1    1    2     3         0        0
# 4       3    0    2     1         0        1

# %%
X_test.head()
# Out:
#    Pclass  Sex  Age  Fare  Embarked  IsAlone
# 0       3    0    2     0         2        1
# 1       3    1    2     0         0        0
# 2       2    0    3     1         2        1
# 3       3    0    1     1         0        1
# 4       3    1    1     1         0        0

# %% [markdown]
# ## Training Our Models and Predicting
#
# ### SVM

# %%
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc
# Out:
# 82.489999999999995

# %% [markdown]
# ### Decision Tree

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree
# Out:
# 85.75

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
lda = LinearDiscriminantAnalysis(solver="svd", store_covariance=True)
Y_pred = lda.fit(X_train, Y_train).predict(X_train)
acc_lda = round(lda.score(X_train,Y_train)*100,2)
acc_lda
# Out:
# 78.560000000000002
